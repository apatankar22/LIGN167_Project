# %%
pip install --upgrade openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 44 kB 1.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 146 kB 9.1 MB/s
# ...
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=bdf44118ca2561e1ff20aab710ab7d75b96c9453ee659568d19863fbf1dd1c77
#   Stored in directory: /root/.cache/pip/wheels/4b/92/33/6f57c7aae0b16875267999a50570e81f15eecec577ebe05a2e
# Successfully built openai
# ...

# %%
import os
import openai

openai.api_key = "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"

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 96 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 62 kB 678 kB/s
# ...
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
tts = gTTS("Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions! How many questions do you time to practice? (I recommend 3 for a quick demo): ")
tts.save('test.wav') 
sound_file = 'test.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
txt = f"The following is a conversation with an AI assistant. \
The assistant is helpful, creative, clever, and very friendly.\n\nHuman: Hello, who are you? \
\nAI: I am an AI created by OpenAI. How can I help you today?\nHuman: \
I am a data science student looking for a internship. I went to school at {uni} and I have a degree in {degree}. I have worked at {exp} and my skills are {skills}. \
Do a mock interview by asking me questions about my education and experiences. Wait until I answer a question before asking me another one\
After I answer a question, you need to ask me another question. Do not answer any questions. \
Do not ask similar questions. \
Ask only 1 question at a time. \nAI:"

# %%
txt2 = f"I am going to give you a question. Pretend you are a college student that studied at {uni}, \
majored in {degree}, has experience working at {exp}, and has skills in {skills}. Answer this question like you are in a job interview: "

# %%
#this complete chunk of code should have the model ask 3 questions 
print("Hi, I'll be your mock interviewer today for behavorial questions!")
intro = gTTS("Hi, I'll be your mock interviewer today for behavorial questions!")
tts.save('intro.wav') 
sound_file = 'intro.wav'
Audio(sound_file, autoplay=True) 
num_questions = int(input("How many questions do you time to practice? (I recommend 3 for a quick demo): ").strip())
for i in range(num_questions):
  input_prompts = txt
  response = openai.Completion.create(
    model="text-davinci-002",
    prompt=input_prompts,
    temperature=0.9,
    max_tokens=150,
    top_p=1,
    frequency_penalty=0.0,
    presence_penalty=0.6,
    stop=[" Human:", " AI:"]
  )

  ai_response = dict(response.get("choices")[0])["text"].strip()
  user_response = input(ai_response + ": ").strip()

  ideal_answer = openai.Completion.create(
    model="text-davinci-002",
    prompt=txt2+ai_response,
    temperature=0.9,
    max_tokens=150,
    top_p=1,
    frequency_penalty=0.0,
    presence_penalty=0.6,
    stop=[" Human:", " AI:"]
  )
  auto_answer = dict(ideal_answer.get("choices")[0])["text"].strip()
  see_answer = int(input("Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: ").strip())
  if see_answer==1:
    print(auto_answer)

print("Well it was great learning more about you! Good luck on your behavorial interview :)")
# Out:
# Hi, I'll be your mock interviewer today for behavorial questions!
# How many questions do you time to practice? (I recommend 3 for a quick demo): 3
# Why did you choose to study data science?: i like math
# Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: 1
# I was originally interested in data science because I liked the idea of working with data to find trends and predict outcomes. I thought it would be a really interesting and challenging field. After doing some research, I decided that data science was the perfect mix of statistics, computer science, and business that I was looking for in a career.
# When did you graduate from UCSD?: 2024
# Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: 2
# Tell me about your experience working at Acumen.: it was nice
# Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: 1
# ...

# %%
# !pip install resume-parser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.2 MB 4.6 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 45.2 MB/s
# ...
#      |████████████████████████████████| 40 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 43.7 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 53.5 MB/s
# ...
#      |████████████████████████████████| 142 kB 72.2 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 31.9 MB/s
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=199fcd878344a43fcfd29794693d9a7e6d12051d71f74a857634110aee5a85d9
#   Stored in directory: /root/.cache/pip/wheels/55/f0/2c/81637d42670985178b77df6d41b9b6c6dc18c94818447414b9
# ...
#   Created wheel for stemming: filename=stemming-1.0.1-py3-none-any.whl size=11138 sha256=3af8e181fe1c9dc90771216e64b8432547ffb8240537d3642e471c16231df629
# ...

# %%
# !pip install nltk

# !pip install spacy==2.3.5

# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz

# !pip install pyresparser!
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.5 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 211 kB 63.7 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 81.1 MB/s
# ...
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.5
#     Uninstalling srsly-2.4.5:
#       Successfully uninstalled srsly-2.4.5
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.3
#     Uninstalling spacy-3.4.3:
# ...

# %%
tts = gTTS("Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions! How many questions do you time to practice? (I recommend 3 for a quick demo): ")
tts.save('test.wav') 
sound_file = 'test.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts = gTTS("Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions! How many questions do you time to practice? (I recommend 3 for a quick demo): ")
tts.save('test.mp3') 
sound_file = 'test.mp3'
Audio(sound_file, autoplay=True) 
os.system("mpg321 test.mp3")
# Out:
# 32512

# %%
def behavorial_questions():
  import os
  import openai
  from google.colab import files
  # from resume_parser import resumeparse

  openai.api_key = "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"

  #do resume cleaning here
  # uni = "UCSD"
  # degree = "Data Science"
  # exp = "Acumen, City of San Diego"
  # skills = "Python, SQL, SAS, Java"
  intro = "Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions! How many questions do you have time to practice? (I recommend 3 for a quick demo): "
  # tts = gTTS("Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions! How many questions do you time to practice? (I recommend 3 for a quick demo): ")
  # tts.save('test.wav') 
  # sound_file = 'test.wav'
  # Audio(sound_file, autoplay=True) 
  num_questions = int(input(intro).strip())
  #delete this all later
  # print("I don't have your resume right now so I need you to answer some basic questions first")
  # name = input("What's your name? ").strip()
  # degree = input("What's your major? ").strip()
  # exp = input("Where have you worked? ").strip()
  # skills = input("What technical skills do you have? (Python, SQL, etc)").strip()
  degree = "Data Science"
  exp = "Dell Technologies, Delta Corporations, Apple, Pearson and Associates"
  uni = "UCSD"
  skills = "Python, Java, C++, SQL, MATLAB, Numpy, Pandas, Matplotlib, Keras, Tensorflow, Scikit-learn, NLP, Computer Vision, Statistics, Multivariable calculus"
  ##################################################################################

  txt = f"The following is a conversation with an AI assistant. \
  The assistant is helpful, creative, clever, and very friendly.\n\nHuman: Hello, who are you? \
  \nAI: I am an AI created by OpenAI. How can I help you today?\nHuman: \
  I am a data science student looking for a internship. I went to school at {uni} and I have a degree in {degree}. I have worked at {exp} and my skills are {skills}. \
  Do a mock interview by asking me questions about my education and experiences. Wait until I answer a question before asking me another one\
  After I answer a question, you need to ask me another question. Do not answer any questions. \
  Do not ask similar questions. \
  Ask only 1 question at a time. \nAI:"

  txt2 = f"I am going to give you a question. Pretend you are a college student that studied at {uni}, \
  majored in {degree}, has experience working at {exp}, and has skills in {skills}. Answer this question like you are in a job interview: "

  for i in range(num_questions):
    input_prompts = txt
    response = openai.Completion.create(
      model="text-davinci-002",
      prompt=input_prompts,
      temperature=0.9,
      max_tokens=150,
      top_p=1,
      frequency_penalty=0.0,
      presence_penalty=0.6,
      stop=[" Human:", " AI:"]
    )

    ai_response = dict(response.get("choices")[0])["text"].strip()
    user_response = input(ai_response + ": ").strip()

    ideal_answer = openai.Completion.create(
      model="text-davinci-002",
      prompt=txt2+ai_response,
      temperature=0.9,
      max_tokens=150,
      top_p=1,
      frequency_penalty=0.0,
      presence_penalty=0.6,
      stop=[" Human:", " AI:"]
    )
    auto_answer = dict(ideal_answer.get("choices")[0])["text"].strip()
    see_answer = int(input("Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: ").strip())
    if see_answer==1:
      print(auto_answer)

  print(f"\n Well it was great learning more about you! Good luck on your behavorial interview :)")

# %%
/
# Out:
# Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions!
# How many questions do you time to practice? (I recommend 3 for a quick demo): 3
# I don't have your resume right now so I need you to answer some basic questions first
# What's your major? Data Science
# Where have you worked? UCSD
# What technical skills do you have? (Python, SQL, etc)Python, SQL
# Tell me about your experiences working with Python.: It is fun!
# Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: 1
# I have been working with Python for a while now and I absolutely love it. I have used it for a variety of tasks, including data analysis, web development, and scientific computing. I find Python to be very versatile and easy to use, and I am confident in my ability to use it for a variety of purposes.
# Tell me about your experience working at UCSD.: It was also fun
# ...

# %%
behavorial_questions()
# Out:
# Hi, I'm Bobby, the chatbox. I'll be your mock interviewer today for behavorial questions! How many questions do you time to practice? (I recommend 3 for a quick demo): 3
# I don't have your resume right now so I need you to answer some basic questions first
# What motivated you to pursue data science?: I'm very interested in math and I wanted a career at the intersection of business and technology
# Would you like to see a sample answer to the question you were just asked. Enter 1 if yes, 2 if no: 1
# I was motivated to pursue data science because I was curious about how data could be used to solve problems and make predictions. I also liked the challenge of working with large amounts of data and finding patterns in it.
# Tell me about your experience working at Dell Technologies.: It was a great learning experience. I worked a lot with Oracle tools and learned more about maintaining security and data integrity
# ...
